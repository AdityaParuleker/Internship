# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #Importing Dataset

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1168, 81)

# %% [markdown]
# - There are 1168 rows and 81 columns in train dataset

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
pd.options.display.max_rows = 81
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df2=pd.read_csv("test.csv")
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df2.shape
# Out:
# (292, 80)

# %% [markdown]
# - There are 292 rows and 80 columns in test dataset

# %% [markdown]
# #Checking Null Values

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       214
# LotArea             0
# Street              0
# Alley            1091
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          7
# MasVnrArea          7
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           30
# BsmtCond           30
# BsmtExposure       31
# BsmtFinType1       30
# BsmtFinSF1          0
# BsmtFinType2       31
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
print("Columns with null values\n")
for i in df:
  if df[i].isnull().sum()>0:
    print(i,":",df[i].isnull().sum())
# Out:
# Columns with null values
#
# LotFrontage : 214
# Alley : 1091
# MasVnrType : 7
# MasVnrArea : 7
# BsmtQual : 30
# BsmtCond : 30
# BsmtExposure : 31
# BsmtFinType1 : 30
# BsmtFinType2 : 31
# FireplaceQu : 551
# GarageType : 64
# GarageYrBlt : 64
# GarageFinish : 64
# GarageQual : 64
# GarageCond : 64
# PoolQC : 1161
# Fence : 931
# MiscFeature : 1124

# %%
a=[]
for i in df:
  if df[i].isnull().sum()>0:
    per=df.shape[0]*0.3
    if df[i].isnull().sum()>per:
      a.append(i)
    
for i in a:
  df=df.drop([i],axis=1)
  df2=df2.drop([i],axis=1)

# %%
print("After dropping we get columns with less than 30% null values\n")
for i in df:
  if df[i].isnull().sum()>0:
    print(i,":",df[i].isnull().sum())
# Out:
# After dropping we get columns with less than 30% null values
#
# LotFrontage : 214
# MasVnrType : 7
# MasVnrArea : 7
# BsmtQual : 30
# BsmtCond : 30
# BsmtExposure : 31
# BsmtFinType1 : 30
# BsmtFinType2 : 31
# GarageType : 64
# GarageYrBlt : 64
# GarageFinish : 64
# GarageQual : 64
# GarageCond : 64

# %%
print("After dropping column with more than 30% missing data\n\nTrain dataset ",df.shape)
print("Test dataset",df2.shape)
# Out:
# After dropping column with more than 30% missing data
#
# Train dataset  (1168, 76)
# Test dataset (292, 75)

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="most_frequent")
for i in df:
  if df[i].isnull().sum()>0:
    if df[i].dtypes==object:
      df[i]=imp.fit_transform(df[i].values.reshape(-1,1))
    else:
      df[i]=df[i].fillna(df[i].mean())

# %%
for i in df2:
  if df2[i].isnull().sum()>0:
    if df2[i].dtypes==object:
      df2[i]=imp.fit_transform(df2[i].values.reshape(-1,1))
    else:
      df2[i]=df2[i].fillna(df2[i].mean())

# %%
for i in df:
  if df[i].isnull().sum()>0:
    print(i,":",df[i].isnull().sum())
  else:
    print("No Null Values remaining in train dataset")
    break
# Out:
# No Null Values remaining in train dataset

# %%
for i in df2:
  if df2[i].isnull().sum()>0:
    print(i,":",df[i].isnull().sum())
  else:
    print("No Null Values remaining in test dataset")
    break
# Out:
# No Null Values remaining in test dataset

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    1168 non-null   float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   LotShape       1168 non-null   object
#  7   LandContour    1168 non-null   object
#  8   Utilities      1168 non-null   object
#  9   LotConfig      1168 non-null   object
#  10  LandSlope      1168 non-null   object
#  11  Neighborhood   1168 non-null   object
#  12  Condition1     1168 non-null   object
#  13  Condition2     1168 non-null   object
#  14  BldgType       1168 non-null   object
#  15  HouseStyle     1168 non-null   object
#  16  OverallQual    1168 non-null   int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    292 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   LotShape       292 non-null    object
#  7   LandContour    292 non-null    object
#  8   Utilities      292 non-null    object
#  9   LotConfig      292 non-null    object
#  10  LandSlope      292 non-null    object
#  11  Neighborhood   292 non-null    object
#  12  Condition1     292 non-null    object
#  13  Condition2     292 non-null    object
#  14  BldgType       292 non-null    object
#  15  HouseStyle     292 non-null    object
#  16  OverallQual    292 non-null    int64
# ...

# %%
for i in df:
  if df[i].dtypes=='float64':
    df[i]=df[i].astype(int)

# %%
for i in df2:
  if df2[i].dtypes=='float64':
    df2[i]=df2[i].astype(int)

# %%
df_test=df2.copy()

# %% [markdown]
# #Visualization

# %%
year_built=pd.DataFrame(df["YearBuilt"].value_counts())
plt.figure(figsize=(70,10))
sns.countplot(df["YearBuilt"])
plt.show()

# %%
year_remod=pd.DataFrame(df["YearRemodAdd"].value_counts())
plt.figure(figsize=(45,10))
sns.countplot(df["YearRemodAdd"])
plt.show()

# %%
listf=["BsmtFullBath","BsmtHalfBath","FullBath","HalfBath","BedroomAbvGr","KitchenAbvGr","TotRmsAbvGrd","Fireplaces","GarageCars"]

# %%
sns.set()
fig,axes=plt.subplots(3,3,figsize=(18,12))
plt.subplots_adjust(bottom=0.1)
j=0
k=0

for i in listf:
  sns.countplot(df[i],ax=axes[j,k])
  print(f"Number of property with {i}")
  print(df[i].value_counts())
  print("\n")
  k=k+1

  
  if k==3:
    k=0
    j=j+1
# Out:
# Number of property with BsmtFullBath
# 0    686
# 1    468
# 2     13
# 3      1
# Name: BsmtFullBath, dtype: int64
#
#
# Number of property with BsmtHalfBath
# 0    1105
# 1      61
# 2       2
# Name: BsmtHalfBath, dtype: int64
#
#
# Number of property with FullBath
# 2    610
# 1    524
# 3     27
# 0      7
# Name: FullBath, dtype: int64
#
#
# Number of property with HalfBath
# 0    724
# 1    434
# 2     10
# Name: HalfBath, dtype: int64
#
#
# Number of property with BedroomAbvGr
# 3    640
# 2    281
# 4    180
# 1     39
# 5     18
# 6      5
# 0      4
# 8      1
# Name: BedroomAbvGr, dtype: int64
#
#
# Number of property with KitchenAbvGr
# 1    1114
# 2      52
# 3       1
# 0       1
# Name: KitchenAbvGr, dtype: int64
#
#
# Number of property with TotRmsAbvGrd
# 6     325
# 7     268
# 5     217
# 8     148
# 4      72
# 9      65
# 10     41
# 11     13
# 3      11
# 12      6
# 2       1
# 14      1
# Name: TotRmsAbvGrd, dtype: int64
#
#
# ...

# %%
sns.set()
fig,axes=plt.subplots(5,7,figsize=(45,15))
plt.subplots_adjust(bottom=0.1)
k=0
j=0
list3=["Exterior1st","Exterior2nd","Neighborhood"]
for i in df:
  if df[i].dtypes==object and i not in list3:
    print(f"Number of property with {i}")
    sns.countplot(y=df[i],ax=axes[j,k])
    print(df[i].value_counts())
    print("\n")
    k=k+1

  
  if k==7:
    k=0
    j=j+1
# Out:
# Number of property with MSZoning
# RL         928
# RM         163
# FV          52
# RH          16
# C (all)      9
# Name: MSZoning, dtype: int64
#
#
# Number of property with Street
# Pave    1164
# Grvl       4
# Name: Street, dtype: int64
#
#
# Number of property with LotShape
# Reg    740
# IR1    390
# IR2     32
# IR3      6
# Name: LotShape, dtype: int64
#
#
# Number of property with LandContour
# Lvl    1046
# Bnk      50
# HLS      42
# Low      30
# Name: LandContour, dtype: int64
#
#
# Number of property with Utilities
# AllPub    1168
# Name: Utilities, dtype: int64
#
#
# Number of property with LotConfig
# Inside     842
# Corner     222
# CulDSac     69
# FR2         33
# FR3          2
# Name: LotConfig, dtype: int64
#
#
# Number of property with LandSlope
# Gtl    1105
# Mod      51
# Sev      12
# Name: LandSlope, dtype: int64
#
#
# Number of property with Condition1
# Norm      1005
# Feedr       67
# Artery      38
# RRAn        20
# PosN        17
# ...

# %%
sns.set()
fig,axes=plt.subplots(5,7,figsize=(50,20))
plt.subplots_adjust(bottom=0.1)
k=0
j=0
list3=["Exterior1st","Exterior2nd","Neighborhood"]
for i in df:
  if df[i].dtypes==object and i not in list3:
    sns.barplot(x=df[i],y=df["SalePrice"],ax=axes[j,k])
    k=k+1

  
  if k==7:
    k=0
    j=j+1

# %% [markdown]
# Highest and lowest sales price in each categorgy.
#
# MSZoning
# - Highest Sales - FV(Floating Village Residential)
# - Lowest Sales - C(Commerical) (all) Zone
#
# Street
# - Highest - paved
# - Lowest - gravel
#
# LotShape
# - Highest - IR2 (Moderately Irregular)
# - Lowest - reg(regular)
#
# Land Contour
# - Highest - HLS	(Hillside - Significant slope from side to side)
# - Lowest -Bnk	(Banked - Quick and significant rise from street grade to building)
#
# Lot Configur
# - Highest - Cul-de-sac
# - Lowest - FR2 (frontage on 2 sides of property)
#
# LandSlope
# - Highest - Sev(Severe slope)
# - Lowest - Gtl(gentle slope)
#
# Condition 1 and Condition 2
# - Highest - PosA(Adjacent to postive off-site feature)
# - Lowest - Artery(Adjacent to arterial street)
#
# BldType
# - Highest - TwnhsE(Townhouse End Unit) and 1Fam	(Single-family Detached)
# - Lowest - Duplx(Duplex)
#
# HouseStyle
# - Highest - 2.5Fin (Two and one-half story: 2nd level finished)
# - Lowest - 1.5Unf (One and one-half story: 2nd level unfinished)
#
# RoofStyle
# - Highest - Shed
# - Lowest - Gambrel
#
# RoofMat
# - Highest - WdShngl	Wood Shingles
# - Lowest - Roll
#
# Foundation
# - Highest - PConc	(Poured Contrete)
# - Lowest - Slab
#
# BsmtFinType1: Rating of basement finished area
# - Highest - GLQ	(Good Living Quarters)
# - Lowest - Rec	(Average Rec Room)
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
# - Highest - GLQ	(Good Living Quarters) and ALQ	Average Living Quarters
# - Lowest - BLQ	(Below Average Living Quarters)
#
# Heating
# - Highest - GasA	(Gas forced warm air furnace)
# - Lowest - Floor	(Floor Furnace)
#
# CentralAir: Central air conditioning
# - Highest - with CentralAir
# - Lowest - Without CentralAir
#
# Electrical
# - Highest - Sbrkr (Standard Circuit Breakers & Romex)
# - Lowest - Mix (Mixed)
#
# Functional
# - Highest -  Typ (Typical Functionality)
# - Lowest - Maj2	(Major Deductions 2)
#
# GarageType
# - Highest - Builtin
# - Lowest - CarPort
#
# PavedDrive
# - Highest - Y (with Paved driveway)
# - Lowest - N (Dirt and gravel)
#
# SaleType
# - Highest - New	(Home just constructed and sold) followed by Con(Contract 15% Down payment regular terms)
# - Lowest - oth (Other)
#
# SaleCondition
# - Highest - Partial i.e Home was not completed when last assessed (associated with New Homes)
# - Lowest - AdjLand (Adjoining Land Purchase)
#
# MasVnrType (Masonry veneer type)
# - Highest - Stone
# - Lowest - None

# %%
p
# Out:
# 0       120
# 1        20
# 2        60
# 3        20
# 4        20
#        ...
# 1163     20
# 1164     20
# 1165    160
# 1166     70
# 1167     60
# Name: MSSubClass, Length: 1168, dtype: object

# %%
p=df["MSSubClass"].copy()
p=p.astype(object)
sns.barplot(y=df["SalePrice"],x=p)

# %% [markdown]
# Sale price for MSSubClass
# - Highest Sale - 60 (2-STORY 1946 & NEWER)
# - Lowest Sale - 30 (1-STORY 1945 & OLDER)

# %%
listnew=["Neighborhood","Exterior1st","Exterior2nd"]

# %%
fig,axes=plt.subplots(2,2,figsize=(20,12))
k=0
j=0
for i in listnew:
  sns.barplot(x=df["SalePrice"],y=df[i],ax=axes[k,j])
  j=j+1
  if j==2:
    j=0
    k=1

# %% [markdown]
# Sale price of housing in each category
#
# Neighborhood
# - Highest Sale - NoRidge
# - Lowest Sale - MeadowV
#
# Exterior1st (Exterior covering on house)
# - Highest - ImStucc	(Imitation Stucco)
# - Lowest - BrkComm (Brick Common)
#
# Exterior2nd
# - Highest - Other
# - Lowest - AsbShng	Asbestos Shingles

# %%
plt.figure(figsize=(15,7))
month_sold=pd.DataFrame(df["MoSold"].value_counts())
palette_color = sns.color_palette('pastel')
plt.pie(month_sold,labels=month_sold.index,colors=palette_color, autopct='%.0f%%')
print("Number of property sold in each month")
print(df["MoSold"].value_counts())
plt.show()
# Out:
# Number of property sold in each month
# 6     203
# 7     187
# 5     166
# 4     113
# 8      95
# 3      87
# 11     67
# 10     66
# 9      57
# 12     46
# 1      44
# 2      37
# Name: MoSold, dtype: int64

# %%
s=pd.DataFrame(df["YrSold"].value_counts())
palette_color = sns.color_palette('pastel')
plt.pie(s,labels=s.index,colors=palette_color, autopct='%.0f%%')
print("Number of property sold in each year")
print(df["YrSold"].value_counts())
plt.show()
# Out:
# Number of property sold in each year
# 2007    264
# 2009    260
# 2006    254
# 2008    248
# 2010    142
# Name: YrSold, dtype: int64

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(30,16))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='white',fmt="0.2f")

# %%
sp=pd.DataFrame(df.corr())
print("Percent correlation of following features with target column SalePrice\n")
round(sp["SalePrice"]*100)
# Out:
# Percent correlation of following features with target column SalePrice
# Id                -2.0
# MSSubClass        -6.0
# LotFrontage       32.0
# LotArea           25.0
# OverallQual       79.0
# OverallCond       -7.0
# YearBuilt         51.0
# YearRemodAdd      51.0
# MasVnrArea        46.0
# BsmtFinSF1        36.0
# BsmtFinSF2        -1.0
# BsmtUnfSF         22.0
# TotalBsmtSF       60.0
# 1stFlrSF          59.0
# 2ndFlrSF          33.0
# LowQualFinSF      -3.0
# GrLivArea         71.0
# BsmtFullBath      21.0
# BsmtHalfBath      -1.0
# FullBath          55.0
# HalfBath          30.0
# BedroomAbvGr      16.0
# KitchenAbvGr     -13.0
# TotRmsAbvGrd      53.0
# Fireplaces        46.0
# GarageYrBlt       46.0
# GarageCars        63.0
# GarageArea        62.0
# WoodDeckSF        32.0
# OpenPorchSF       34.0
# EnclosedPorch    -12.0
# 3SsnPorch          6.0
# ScreenPorch       10.0
# PoolArea          10.0
# MiscVal           -1.0
# MoSold             7.0
# YrSold            -5.0
# ...

# %%
plt.figure(figsize=(20,7))
k = 10 
cols = df.corr().nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
plt.figure(figsize=(22,7))
df.corr()["SalePrice"].sort_values(ascending=False).drop(["SalePrice"]).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# Negative correlation with traget colum
# - Max -ve correlation: KitchenAbvGr
# - Min -ve correlation: BsmtFinSF2
#
# Positive correlation with traget colum
# - Max +ve correlation: 3SsnPorch
# - Min +ve correlation: OverallQual

# %% [markdown]
# #Describing Data

# %%
df.iloc[:,65:].describe()
# Out:
#        OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea  \
# count  1168.000000    1168.000000  1168.000000  1168.000000  1168.000000
# mean     46.559932      23.015411     3.639555    15.051370     3.448630
# std      66.381023      63.191089    29.088867    55.080816    44.896939
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     0.000000
# 50%      24.000000       0.000000     0.000000     0.000000     0.000000
# 75%      70.000000       0.000000     0.000000     0.000000     0.000000
# max     547.000000     552.000000   508.000000   480.000000   738.000000
#
#             MiscVal       MoSold       YrSold      SalePrice
# count   1168.000000  1168.000000  1168.000000    1168.000000
# mean      47.315068     6.344178  2007.804795  181477.005993
# std      543.264432     2.686352     1.329738   79105.586863
# min        0.000000     1.000000  2006.000000   34900.000000
# ...

# %%
plt.figure(figsize=(40,12))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='white',fmt="0.2f")

# %% [markdown]
# Id
# - mean -	724.136130
# - std	- 416.159877
# - min	- 1.000000
# - max	- 1460.000000
#
# MSSubClass
# - mean -	56.767979
# - std	- 41.940650
# - min	- 20.000000
# - max	- 	190.000000
#
# LotFrontage
# - mean -	70.988470
# - std	- 22.437056
# - min	- 21.000000
# - max	- 313.000000
#
# LotArea
# - mean -	10484.749144
# - std	- 8957.442311
# - min	- 1300.000000
# - max	- 164660.000000
#
# OverallQual
# - mean -	6.104452
# - std	- 1.390153
# - min	- 1.000000
# - max	- 10.000000
#
# OverallCond
# - mean -	5.595890
# - std	- 1.124343
# - min	- 1.000000
# - max	- 9.000000
#
# YearBuilt
# - mean -	1970.930651
# - std	- 30.145255
# - min	- 1875.000000
# - max	-	2010.000000
#
# YearRemodAdd
# - mean -	1984.758562
# - std	- 20.785185
# - min	-	1950.000000
# - max	- 2010.000000
#
# MasVnrArea
# - mean -	102.310078
# - std	- 182.047152
# - min	-		0.000000
# - max	- 	1600.000000
#
# BsmtFinSF1
# - mean -	444.726027
# - std	- 462.664785
# - min	-	0.000000
# - max	- 5644.000000
#
# BsmtFinSF2
# - mean - 46.647260
# - std	- 163.520016
# - min	-	0.000000
# - max	- 1474.000000
# BsmtUnfSF
# - mean -	569.721747
# - std	- 449.375525
# - min	-	0.000000
# - max	- 2336.000000
#
# TotalBsmtSF
# - mean -		1061.095034
# - std	- 442.272249
# - min	-		0.000000
# - max	- 	6110.000000
#
# 1stFlrSF
# - mean -	1169.860445
# - std -	391.161983
# - min -	334.000000
# - max -	4692.000000
#
# 2ndFlrSF
# - mean -	348.826199
# - std -	439.696370
# - min -	0.000000
# - max -	2065.000000
#
# LowQualFinSF
# - mean -		6.380137
# - std -		50.892844
# - min -		0.000000
# - max -	572.000000
#
# GrLivArea
# - mean -	1525.066781
# - std -	528.042957
# - min -	334.000000
# - max -	5642.000000
#
# BsmtFullBath
# - mean -	0.425514
# - std -	0.521615
# - min -	0.000000
# - max -	3.000000
#
# BsmtHalfBath
# - mean -	0.055651
# - std -	0.236699
# - min -	0.000000
# - max -	2.000000
#
# FullBath
# - mean - 1.562500
# - std -	0.551882
# - min -	0.000000
# - max -	3.000000
#
# HalfBath
# - mean -	0.388699
# - std -	0.504929
# - min -	0.000000
# - max -	2.000000
#
# BedroomAbvGr
# - mean -	2.884418
# - std -	0.817229
# - min -	0.000000
# - max -	8.000000
#
# KitchenAbvGr
# - mean -	1.045377
# - std -	0.216292
# - min -	0.000000
# - max -	3.000000
#
# TotRmsAbvGrd
# - mean -	6.542808
# - std -	1.598484
# - min -	2.000000
# - max -	14.000000
#
# Fireplaces
# - mean -	0.617295
# - std -	0.650575
# - min -	0.000000
# - max -	3.000000
#
# GarageYrBlt
# - mean -	1978.193841
# - std -	24.198559
# - min -	1900.000000
# - max -	2010.000000
#
# GarageCars
# - mean -	1.776541
# - std -	0.745554
# - min -	0.000000
# - max -	4.000000
#
# GarageArea
# - mean -	476.860445
# - std -	214.466769
# - min -	0.000000
# - max -	1418.000000
#
# WoodDeckSF
# - mean -	96.206336
# - std -	126.158988
# - min -	0.000000
# - max -	857.000000
#
# OpenPorchSF
# - mean -	46.559932
# - std	- 66.381023
# - min -	0.000000
# - max	- 547.000000
#
# EnclosedPorch
# - mean -	23.015411
# - std	- 63.191089
# - min -	0.000000
# - max	- 552.000000
#
# 3SsnPorch
# - mean -		3.639555
# - std	- 29.088867
# - min -	0.000000
# - max	- 508.000000
#
# ScreenPorch
# - mean -	15.051370
# - std	- 55.080816
# - min -	0.000000
# - max	- 480.000000
#
# PoolArea
# - mean -	3.448630
# - std	- 44.896939
# - min -	0.000000
# - max	- 738.000000
#
# MiscVal
# - mean -		47.315068
# - std	- 543.264432
# - min -	0.000000
# - max	- 	15500.000000
#
# MoSold
# - mean - 6.344178
# - std	- 2.686352
# - min -	1.000000
# - max	- 12.000000
#
# YrSold
# - mean -	2007.804795
# - std	- 1.329738
# - min -		2006.000000
# - max	- 2010.000000
#
# SalePrice
# - mean -	181477.005993
# - std	- 79105.586863
# - min -34900.000000
# - max	- 755000.000000

# %% [markdown]
# #Detecting Outliers

# %%
fig, ax = plt.subplots()
ax.scatter(x = df['GrLivArea'], y = df['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# - In above graph there are two outlier indicating very big area at very cheap price, which is not possible. Hence it is safe to remove these outliers only because they are extremely big.

# %%
df = df.drop(df[(df['GrLivArea']>4000) & (df['SalePrice']<300000)].index)
fig, ax = plt.subplots()
ax.scatter(df['GrLivArea'], df['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# - Removing all outliers might affect our model, hence we avoid it.

# %% [markdown]
# #Separating input and target features

# %%
x=df.drop(["Id","SalePrice"],axis=1)
x.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL           70     4928   Pave      IR1         Lvl
# 1          20       RL           95    15865   Pave      IR1         Lvl
# 2          60       RL           92     9920   Pave      IR1         Lvl
# 3          20       RL          105    11751   Pave      IR1         Lvl
# 4          20       RL           70    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0    AllPub    Inside       Gtl  ...         205             0         0
# 1    AllPub    Inside       Mod  ...         207             0         0
# 2    AllPub   CulDSac       Gtl  ...         130             0         0
# 3    AllPub    Inside       Gtl  ...         122             0         0
# 4    AllPub       FR2       Gtl  ...           0             0         0
#
#   ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition
# ...

# %%
y=df["SalePrice"]
y.head()
# Out:
# 0    128000
# 1    268000
# 2    269790
# 3    190000
# 4    215000
# Name: SalePrice, dtype: int64

# %% [markdown]
# # Detecting Skewness

# %%
x.skew().sort_values()
# Out:
# GarageYrBlt      -0.660371
# YearBuilt        -0.577729
# YearRemodAdd     -0.493680
# GarageCars       -0.358359
# FullBath          0.051358
# YrSold            0.114730
# GarageArea        0.130865
# OverallQual       0.154541
# MoSold            0.225452
# BedroomAbvGr      0.244383
# TotalBsmtSF       0.511376
# OverallCond       0.578163
# BsmtFullBath      0.620581
# TotRmsAbvGrd      0.622602
# Fireplaces        0.651401
# HalfBath          0.661602
# BsmtFinSF1        0.771761
# 2ndFlrSF          0.823739
# BsmtUnfSF         0.909799
# 1stFlrSF          0.935000
# GrLivArea         1.015988
# MSSubClass        1.421222
# WoodDeckSF        1.510249
# LotFrontage       1.973091
# OpenPorchSF       2.382516
# MasVnrArea        2.864055
# EnclosedPorch     3.040256
# ScreenPorch       4.101650
# BsmtHalfBath      4.260178
# KitchenAbvGr      4.360959
# BsmtFinSF2        4.361584
# LowQualFinSF      8.658447
# 3SsnPorch         9.762016
# LotArea          11.118882
# ...

# %% [markdown]
# Keeping +/- 0.5 as the range of skewness, the numeric features that contain skewness are listed in below list1

# %%
list1=["BsmtFullBath",     
"TotRmsAbvGrd",      
"HalfBath",          
"Fireplaces",        
"2ndFlrSF",          
"BsmtUnfSF",                
"GrLivArea",         
"WoodDeckSF",        
"1stFlrSF",         
"TotalBsmtSF",       
"BsmtFinSF1",       
"OpenPorchSF",       
"LotFrontage",       
"MasVnrArea",        
"EnclosedPorch",     
"ScreenPorch",       
"BsmtHalfBath",      
"KitchenAbvGr",      
"BsmtFinSF2",      
"LowQualFinSF",     
"3SsnPorch",         
"LotArea",          
"PoolArea",        
"MiscVal"]

# %%
len(list1)
# Out:
# 24

# %%
sns.set()
fig,axes=plt.subplots(5,5,figsize=(22,18))
plt.subplots_adjust(bottom=0.1)
k=0
j=0
for i in list1:
    sns.distplot(x[i],ax=axes[j,k])
    axes[j,k].set_ylabel(" ")
    k=k+1
    
    if k==5:
      k=0
      j=j+1

# %% [markdown]
# Following features are of discrete numeric type
#
# - "BsmtFullBath",
# - "TotRmsAbvGrd",
# - "HalfBath",
# - "Fireplaces",
# - "BsmtHalfBath",
# - "KitchenAbvGr",

# %%
from sklearn.preprocessing import QuantileTransformer
qt=QuantileTransformer()
for i in list1:
  x[i]=qt.fit_transform(x[i].values.reshape(-1,1))
  df_test[i]=qt.fit_transform(df_test[i].values.reshape(-1,1))

# %%
sns.set()
fig,axes=plt.subplots(5,5,figsize=(22,18))
plt.subplots_adjust(bottom=0.1)
k=0
j=0
for i in list1:
    sns.distplot(x[i],ax=axes[j,k])
    axes[j,k].set_ylabel(" ")
    k=k+1
    
    if k==5:
      k=0
      j=j+1

# %%
x["MasVnrArea"].mean()
# Out:
# 0.3239965925661894

# %%
print("Skewness remaining in features after tranforming\n")
list2=[]
for i in list1:
  if x[i].skew()>0.51:
      print(i,"-",round(x[i].skew(),2))
      list2.append(i)
# Out:
# Skewness remaining in features after tranforming
#
# EnclosedPorch - 2.03
# ScreenPorch - 3.07
# BsmtHalfBath - 3.95
# KitchenAbvGr - 4.16
# BsmtFinSF2 - 2.4
# LowQualFinSF - 6.92
# 3SsnPorch - 7.08
# PoolArea - 13.85
# MiscVal - 4.99

# %%
from sklearn.preprocessing import QuantileTransformer
sns.set()
fig,axes=plt.subplots(3,3,figsize=(12,7))
plt.subplots_adjust(bottom=0.1)
k=0
j=0
print("We check if the skewness remaining in some of the features can be removed,\n")
for i in list2:
    x[i]=np.cbrt(x[i].values.reshape(-1,1))
    sns.distplot(x[i],ax=axes[j,k])
    print(i,":",round(x[i].skew(),2))
    axes[j,k].set_ylabel(" ")
    k=k+1
    
    if k==3:
      k=0
      j=j+1
# Out:
# We check if the skewness remaining in some of the features can be removed,
#
# EnclosedPorch : 2.02
# ScreenPorch : 3.06
# BsmtHalfBath : 3.95
# KitchenAbvGr : -0.4
# BsmtFinSF2 : 2.39
# LowQualFinSF : 6.92
# 3SsnPorch : 7.08
# PoolArea : 13.85
# MiscVal : 4.99

# %% [markdown]
# - Only KitchenAbvGr has been reduced in range of skewness.

# %%
list2.remove("KitchenAbvGr")
for i in list2:
  x=x.drop([i],axis=1)
  df_test=df_test.drop([i],axis=1)

# %%
x.skew().sort_values()
# Out:
# GarageYrBlt    -0.660371
# YearBuilt      -0.577729
# YearRemodAdd   -0.493680
# KitchenAbvGr   -0.403055
# GarageCars     -0.358359
# BsmtFinSF1     -0.138751
# BsmtUnfSF      -0.055137
# TotalBsmtSF    -0.006187
# LotFrontage    -0.000988
# LotArea         0.000045
# 1stFlrSF        0.000139
# GrLivArea       0.000167
# Fireplaces      0.011047
# TotRmsAbvGrd    0.021946
# FullBath        0.051358
# OpenPorchSF     0.088519
# YrSold          0.114730
# GarageArea      0.130865
# OverallQual     0.154541
# MoSold          0.225452
# BedroomAbvGr    0.244383
# WoodDeckSF      0.247285
# BsmtFullBath    0.370115
# 2ndFlrSF        0.403304
# MasVnrArea      0.486961
# HalfBath        0.506374
# OverallCond     0.578163
# MSSubClass      1.421222
# dtype: float64

# %% [markdown]
# #Encoding Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
lenc=LabelEncoder()
oenc=OrdinalEncoder()
listenc=["LotShape","LandSlope","ExterQual","ExterCond","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1",
       "BsmtFinType2","HeatingQC","KitchenQual","Functional","GarageFinish","GarageQual","GarageCond"]
for i in x:
  if x[i].dtypes==object:
    if i in listenc:
      x[i]=oenc.fit_transform(x[i].values.reshape(-1,1))
    else:
      x[i]=lenc.fit_transform(x[i].values.reshape(-1,1))

x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0         120         3     0.509510  0.092092       1       0.0            3
# 1          20         3     0.913914  0.930895       1       0.0            3
# 2          60         3     0.898398  0.564064       1       0.0            3
# 3          20         3     0.951952  0.764136       1       0.0            3
# 4          20         3     0.509510  0.941875       1       0.0            3
#
#    Utilities  LotConfig  LandSlope  ...  GarageArea  GarageQual  GarageCond  \
# 0          0          4        0.0  ...         440         4.0         4.0
# 1          0          4        1.0  ...         621         4.0         4.0
# 2          0          1        0.0  ...         455         4.0         4.0
# 3          0          4        0.0  ...         546         4.0         4.0
# 4          0          2        0.0  ...         529         4.0         4.0
#
# ...

# %%
for i in x:
  if len(x[i].unique())<2:
    x[i]=x[i].replace(0,1)

# %%
for i in df_test:
  if df_test[i].dtypes==object:
    if i in listenc:
      df_test[i]=oenc.fit_transform(df_test[i].values.reshape(-1,1))
    else:
      df_test[i]=lenc.fit_transform(df_test[i].values.reshape(-1,1))

df_test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0   337          20         2     0.883162  0.886598       1       0.0
# 1  1018         120         2     0.534364  0.158076       1       0.0
# 2   929          20         2     0.534364  0.762887       1       3.0
# 3  1148          70         2     0.735395  0.783505       1       3.0
# 4  1227          60         2     0.883162  0.903780       1       0.0
#
#    LandContour  Utilities  LotConfig  ...  GarageArea  GarageQual  GarageCond  \
# 0            1          0          0  ...         676         4.0         4.0
# 1            3          0          1  ...         565         4.0         4.0
# 2            3          0          4  ...         522         4.0         4.0
# 3            0          0          4  ...         234         4.0         4.0
# 4            3          0          1  ...         668         4.0         4.0
#
#    PavedDrive  WoodDeckSF  OpenPorchSF  MoSold  YrSold  SaleType  \
# ...

# %%
for i in df_test:
  if len(df_test[i].unique())<2:
    df_test[i]=df_test[i].replace(0,1)

# %% [markdown]
# # Detecting Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
pd.options.display.max_rows = 66
calc_vif(x)
# Out:
#         variables           VIF
# 0      MSSubClass  5.136860e+00
# 1        MSZoning  1.366899e+00
# 2     LotFrontage  1.961785e+00
# 3         LotArea  2.269583e+00
# 4          Street  1.110466e+00
# 5        LotShape  1.294240e+00
# 6     LandContour  1.331835e+00
# 7       Utilities  2.513055e+06
# 8       LotConfig  1.142328e+00
# 9       LandSlope  1.438844e+00
# 10   Neighborhood  1.274776e+00
# 11     Condition1  1.148210e+00
# 12     Condition2  1.092330e+00
# 13       BldgType  4.829072e+00
# 14     HouseStyle  2.239175e+00
# 15    OverallQual  3.896840e+00
# 16    OverallCond  1.920918e+00
# 17      YearBuilt  7.404956e+00
# 18   YearRemodAdd  2.908879e+00
# 19      RoofStyle  1.256723e+00
# 20       RoofMatl  1.166112e+00
# 21    Exterior1st  4.265734e+00
# 22    Exterior2nd  4.282712e+00
# 23     MasVnrType  1.527855e+00
# 24     MasVnrArea  2.018883e+00
# 25      ExterQual  2.591852e+00
# 26      ExterCond  1.213694e+00
# 27     Foundation  2.048368e+00
# ...

# %% [markdown]
# - Vif>5 indicates multicollinearity

# %%
X=x.drop(["Utilities","Street","YrSold","GarageYrBlt"],axis=1)
calc_vif(X)
# Out:
#         variables           VIF
# 0      MSSubClass     14.191583
# 1        MSZoning     30.958144
# 2     LotFrontage      7.878862
# 3         LotArea      8.938059
# 4        LotShape      3.711821
# 5     LandContour     22.159116
# 6       LotConfig      4.949587
# 7       LandSlope      1.495083
# 8    Neighborhood      6.452441
# 9      Condition1      7.378487
# 10     Condition2     74.941688
# 11       BldgType      5.504533
# 12     HouseStyle      7.782008
# 13    OverallQual     78.313021
# 14    OverallCond     48.363212
# 15      YearBuilt  17241.878237
# 16   YearRemodAdd  17040.030677
# 17      RoofStyle      4.788202
# 18       RoofMatl      1.179480
# 19    Exterior1st     37.601005
# 20    Exterior2nd     35.575717
# 21     MasVnrType     14.097649
# 22     MasVnrArea      3.319271
# 23      ExterQual     36.386030
# 24      ExterCond     31.386449
# 25     Foundation      9.110126
# 26       BsmtQual     17.993721
# 27       BsmtCond     21.567365
# ...

# %%
X_test=df_test.drop(["Utilities","Street","YrSold","GarageYrBlt"],axis=1)

# %% [markdown]
# #Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
s=mns.fit_transform(X)
x=pd.DataFrame(data=s)

# %%
p=mns.fit_transform(X_test)
test_data=pd.DataFrame(data=p)

# %% [markdown]
# #PCA

# %%
from sklearn.decomposition import PCA
pca=PCA().fit(x)

plt.rcParams["figure.figsize"]=(30,7)

fig,ax=plt.subplots()
a=np.arange(1,63,step=1)
b=np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(a,b,marker='o',linestyle='--',color='b')

plt.xlabel("Number of comonents currently present in dataset")
plt.xticks(np.arange(0,62,step=1))
plt.ylabel("Cumulative variance (%)")
plt.title("Number of components required")

plt.axhline(y=0.99,color='r',linestyle='-')
plt.text(0.90, 0.90, '99% cut-off threshold', color = 'red', fontsize=15)
ax.grid(axis='x')
plt.show()

# %%
pca=PCA(n_components=50)
pca.fit(x)
x=pca.transform(x)
x.shape
# Out:
# (1166, 50)

# %%
pca=PCA(n_components=50)
pca.fit(test_data)
testdf=pca.transform(test_data)
testdf.shape
# Out:
# (292, 50)

# %% [markdown]
# #Training

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
for i in range(100):
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
  lr.fit(x,y)
  pred_train=lr.predict(x_train)
  pred_test=lr.predict(x_test)
  print("At Random State : ",i)
  print("Training r2: ",round(r2_score(y_train,pred_train)*100,2))
  print("Testing r2: ",round(r2_score(y_test,pred_test)*100,2))
  print("\n")
# Out:
# At Random State :  0
# Training r2:  85.82
# Testing r2:  80.82
#
#
# At Random State :  1
# Training r2:  84.02
# Testing r2:  85.62
#
#
# At Random State :  2
# Training r2:  85.83
# Testing r2:  79.04
#
#
# At Random State :  3
# Training r2:  84.49
# Testing r2:  83.85
#
#
# At Random State :  4
# Training r2:  85.03
# Testing r2:  81.44
#
#
# At Random State :  5
# Training r2:  84.72
# Testing r2:  82.41
#
#
# At Random State :  6
# Training r2:  84.51
# Testing r2:  83.78
#
#
# At Random State :  7
# Training r2:  85.84
# Testing r2:  78.8
#
#
# At Random State :  8
# Training r2:  82.44
# Testing r2:  90.59
#
#
# At Random State :  9
# Training r2:  83.77
# Testing r2:  86.28
#
#
# At Random State :  10
# Training r2:  83.96
# Testing r2:  86.13
#
#
# At Random State :  11
# Training r2:  83.7
# Testing r2:  87.28
#
#
# At Random State :  12
# Training r2:  83.25
# Testing r2:  88.86
#
#
# At Random State :  13
# Training r2:  83.31
# Testing r2:  89.49
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=98)
lr.fit(x,y)
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
print("Training r2: ",round(r2_score(y_train,pred_train)*100,2))
print("Testing r2: ",round(r2_score(y_test,pred_test)*100,2))
print("\n")
print("mean_absolute_error: ",mean_absolute_error(y_test,pred_test))
print("mean_squared_error: ",mean_squared_error(y_test,pred_test))
print("Root mean_square: ",np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# Training r2:  84.53
# Testing r2:  83.58
#
#
# mean_absolute_error:  19839.738821698782
# mean_squared_error:  904365314.2416205
# Root mean_square:  30072.66722859182

# %% [markdown]
# #Cross Validation

# %%
ls=r2_score(y_test,pred_test)
for j in range(2,20):
  cv_score=cross_val_score(lr,x,y,cv=j)
  print(cv_score)
  print("At cv: ",j)
  print("Cross Validation Score: ",round(cv_score.mean()*100,2))
  print("r2 Score: ",round(ls*100,2))
  print("\n")
# Out:
# [0.80298097 0.81801838]
# At cv:  2
# Cross Validation Score:  81.05
# r2 Score:  83.58
#
#
# [0.82000494 0.82608379 0.82507458]
# At cv:  3
# Cross Validation Score:  82.37
# r2 Score:  83.58
#
#
# [0.80891616 0.8198498  0.82176157 0.84245302]
# At cv:  4
# Cross Validation Score:  82.32
# r2 Score:  83.58
#
#
# [0.80414258 0.8214935  0.80924006 0.84534739 0.83388531]
# At cv:  5
# Cross Validation Score:  82.28
# r2 Score:  83.58
#
#
# [0.80308749 0.84135588 0.8148947  0.81846783 0.83126902 0.8382791 ]
# At cv:  6
# Cross Validation Score:  82.46
# r2 Score:  83.58
#
#
# [0.79904323 0.82318547 0.81676019 0.81315659 0.84612975 0.8375808
#  0.83140213]
# At cv:  7
# Cross Validation Score:  82.39
# r2 Score:  83.58
#
#
# [0.79726321 0.83517676 0.84541477 0.79305356 0.81469233 0.82872912
#  0.84669645 0.83637057]
# At cv:  8
# Cross Validation Score:  82.47
# r2 Score:  83.58
#
#
# [0.87123002 0.7613728  0.86351136 0.79589968 0.78084765 0.84449439
#  0.82293687 0.84628826 0.84115825]
# ...

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso

parameters={'alpha':[.00001,.0001,.001,.01,.1,1,10],
            'random_state': list(range(0,10)),
            'selection':['cyclic', 'random'],
            'fit_intercept': ['True','False']}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'fit_intercept': 'True', 'random_state': 6, 'selection': 'random'}

# %%
from sklearn.linear_model import Lasso
ls=Lasso(alpha=10,random_state=6,fit_intercept=True,selection='random')
ls.fit(x_train,y_train)
ls_score_train=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
print("Training Accuracy: ",round(ls_score_train*100,2))
# Out:
# Training Accuracy:  84.77

# %%
lss=r2_score(y_test,pred_ls)
print("Testing Accuracy: ",round(lss*100,2))
# Out:
# Testing Accuracy:  80.89

# %%
cv_score=cross_val_score(ls,x,y,cv=8)
cv_mean=cv_score.mean()
print("Cross Validation Score: ",round(cv_mean*100,2))
# Out:
# Cross Validation Score:  82.51

# %% [markdown]
# #Model Selection

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

def model_selection(algorithm_instance,x_train,y_train,x_test,y_test):
    algorithm_instance.fit(x_train,y_train)
    model_pred_train=algorithm_instance.predict(x_train)
    model_pred_test=algorithm_instance.predict(x_test)
    print("Accuracy of training model :",round(r2_score(y_train,model_pred_train)*100,2))
    print("Accuracy of test data :",round(r2_score(y_test,model_pred_test)*100,2))
    rfscore=cross_val_score(algorithm_instance,x,y,cv=8)
    rfc=rfscore.mean()
    print('Cross Val Score:',round(rfc*100,2))
    print("\nMean Absolute Error ",mean_absolute_error(y_test,model_pred_test))
    print("Mean Sq. Error ",mean_squared_error(y_test,model_pred_test))
    print("Root Mean Sq ",np.sqrt(mean_squared_error(y_test,model_pred_test)))
    print("\n")

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xg
xgb = xg.XGBRegressor()
model_selection(xgb,x_train,y_train,x_test,y_test)
# Out:
# [06:36:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Accuracy of training model : 96.83
# Accuracy of test data : 85.9
# [06:36:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:36:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:36:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:36:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:36:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:36:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
from sklearn.linear_model import BayesianRidge
br = BayesianRidge()
model_selection(br,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 84.7
# Accuracy of test data : 81.59
# Cross Val Score: 82.61
#
# Mean Absolute Error  21241.713391318455
# Mean Sq. Error  1014295488.2646353
# Root Mean Sq  31848.006032790112

# %%
from sklearn.linear_model import SGDRegressor
sgdr=SGDRegressor()
model_selection(sgdr,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 84.71
# Accuracy of test data : 81.47
# Cross Val Score: 82.58
#
# Mean Absolute Error  21419.75850707797
# Mean Sq. Error  1021078579.7847084
# Root Mean Sq  31954.320205329175

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
model_selection(knr,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 84.8
# Accuracy of test data : 74.27
# Cross Val Score: 77.37
#
# Mean Absolute Error  23992.876923076925
# Mean Sq. Error  1417461629.2502563
# Root Mean Sq  37649.19161483094

# %% [markdown]
# # Ensemble Methods

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameter={'criterion':['mse','mae'],
          'max_features' : ["auto","sqrt","log2"],
          'n_estimators':range(0,100,25)}

rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto', 'n_estimators': 75}

# %%
rf=RandomForestRegressor(criterion='mse',max_features="auto", n_estimators=75)
model_selection(rf,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 97.49
# Accuracy of test data : 83.07
# Cross Val Score: 82.31
#
# Mean Absolute Error  22291.65903133903
# Mean Sq. Error  932605638.1857383
# Root Mean Sq  30538.59260322483

# %% [markdown]
# # AdaBoostRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor

parameter={'loss':['linear', 'square', 'exponential'],
          'random_state' : range(0,100,25),
           'learning_rate':[0,1.0],
           'n_estimators':range(0,100,25)}

rf2=AdaBoostRegressor()
clf=GridSearchCV(rf2,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'learning_rate': 1.0, 'loss': 'exponential', 'n_estimators': 50, 'random_state': 50}

# %%
from sklearn.ensemble import AdaBoostRegressor
rf2=AdaBoostRegressor(learning_rate= 1.0, loss= 'exponential', n_estimators= 50, random_state= 50)
model_selection(rf2,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 86.88
# Accuracy of test data : 79.02
# Cross Val Score: 77.25
#
# Mean Absolute Error  27285.534809653953
# Mean Sq. Error  1155563673.8267894
# Root Mean Sq  33993.58283304055

# %% [markdown]
# # GradientBoostingRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

parameter={'loss':['squared_error', 'absolute_error', 'huber','quantile'],
          'criterion':['friedman_mse', 'squared_error', 'mse'],
           'learning_rate':[0,1.0],
           'n_estimators':range(0,100,25)}

rf3=GradientBoostingRegressor()
clf=GridSearchCV(rf3,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'squared_error', 'learning_rate': 1.0, 'loss': 'absolute_error', 'n_estimators': 25}

# %%
rf3=GradientBoostingRegressor(learning_rate= 1.0, loss= 'absolute_error', n_estimators= 25, criterion= 'squared_error')
model_selection(rf3,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 86.81
# Accuracy of test data : 73.88
# Cross Val Score: 76.47
#
# Mean Absolute Error  26532.68376068376
# Mean Sq. Error  1439018194.4273505
# Root Mean Sq  37934.39329193694

# %% [markdown]
# # BaggingRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor

parameter={'oob_score':['True','False'],
          'n_jobs':range(0,10,2),
           'random_state':range(0,100,25),
           'n_estimators':range(0,100,25)}

rf4=BaggingRegressor()
clf=GridSearchCV(rf4,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'n_estimators': 75, 'n_jobs': 2, 'oob_score': 'True', 'random_state': 75}

# %%
rf4=BaggingRegressor(oob_score= True, n_jobs= 2, n_estimators= 75, random_state= 75)
model_selection(rf4,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 97.27
# Accuracy of test data : 82.42
# Cross Val Score: 82.12
#
# Mean Absolute Error  22688.51680911681
# Mean Sq. Error  968735484.1911474
# Root Mean Sq  31124.5158065334

# %% [markdown]
# # VotingRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import VotingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

estimators = [ ('knc', KNeighborsRegressor()), ('svr',SVR()) ]
parameter={
          'n_jobs':range(0,10,2),
           'verbose':[True,False]
          }

rf5=VotingRegressor(estimators)
clf=GridSearchCV(rf5,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'n_jobs': 2, 'verbose': True}

# %%
rf5=VotingRegressor(estimators, n_jobs= 2, verbose= True)
model_selection(rf5,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 58.26
# Accuracy of test data : 51.9
# Cross Val Score: 54.0
#
# Mean Absolute Error  33891.26849109056
# Mean Sq. Error  2649875780.7529373
# Root Mean Sq  51476.944166810616

# %% [markdown]
# #Saving Model

# %%
import pickle
filename='rfz.pk1'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# - Linear Regression model was choosen since it has the lowest Mean Absolute Error among all the tested model.

# %% [markdown]
# #Loading Saved Model

# %%
loaded_model=pickle.load(open('rfz.pk1','rb'))
result=loaded_model.score(x_test,y_test)
print("\nModel Accuracy:",result*100)
# Out:
# Model Accuracy: 83.5839233259194

# %% [markdown]
# # Predicting Output in Test Model

# %%
testdf_output=pd.DataFrame(loaded_model.predict(testdf),columns=["SalePrice"])
testdf_output.head()
# Out:
#        SalePrice
# 0  310841.236102
# 1  239939.110994
# 2  277423.921478
# 3  145476.749451
# 4  260205.189674

# %%
test2=pd.concat([df2,testdf_output],axis=1)
test2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0   337          20       RL           86    14157   Pave      IR1
# 1  1018         120       RL           66     5814   Pave      IR1
# 2   929          20       RL           66    11838   Pave      Reg
# 3  1148          70       RL           75    12000   Pave      Reg
# 4  1227          60       RL           86    14598   Pave      IR1
#
#   LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0         HLS    AllPub    Corner  ...             0         0           0
# 1         Lvl    AllPub   CulDSac  ...             0         0           0
# 2         Lvl    AllPub    Inside  ...             0         0           0
# 3         Bnk    AllPub    Inside  ...             0         0           0
# 4         Lvl    AllPub   CulDSac  ...             0         0           0
#
#   PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
test2.shape
# Out:
# (292, 76)

# %% [markdown]
# #Conclusion

# %% [markdown]
# - We found that OverallQual, GrLivArea, TotalBsmtSF, Garage Car, Garage Area, 1stFlrSF, Full Bath, TotRmsAbvGrd and YearBuilt are the most important features among in predicting the housing sales price.
#
# - OverallQual rating of the housing played a key part in sale price; the maintained houses with equipped facilities were allocated with higher rate when compared to the less maintained ones with no facilities.
#
# - GrLivArea (i.e. above ground living area) and TotalBsmtSF (i.e. Total basement area), impacted the sales price based on the area; larger the area more is the price.
#
# - The housing with GarageArea (Size of garage in square feet) and GarageCars (Size of garage in car capacity) also significantly impacted the sale peice.
#
# - Year of construction signified that, the houses that were newly built were more expensive than the old ones.
#
# - Higher the number of TotRmsAbvGrd (Total rooms above grade) and FullBath (Full bathrooms above grade) in house, more was the price of the house.
