# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #Importing Dataset

# %%
df=pd.read_excel("customer_retention_dataset.xlsx")
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# - Dataset has 269 rows and 71 columns.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# **Detecting if any non object column exist**

# %%
j=df.columns[0]
k=0
n=0
for i in df.dtypes:
  if i!=object:
    print(f"index {k}, '{j}',", i)
  k=k+1
  n=n+1
  if n!=df.shape[1]:
    j=df.columns[0+n]
# Out:
# index 3, '4 What is the Pin Code of where you shop online from?', int64

# %% [markdown]
# - Found 1 non object column
# - Pincode is considered object

# %% [markdown]
# #Checking Null Values

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
a=[]
b=[]
j=0
for i in df.isnull().sum():
  if i !=0:
    print(f"Null value at Col {j} : {i}")
    a.append(f"Col {j} : {i}")
  j=j+1


if len(a)==0:
  print("No Null Values")
# Out:
# No Null Values

# %% [markdown]
# - There are no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# #Personal Details and Choice

# %%
sns.countplot(y=df["1Gender of respondent"])
print(df["1Gender of respondent"].value_counts())
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# Gender of the respondent
# - There are 181 Female respondents
# - And 88 Male respondents

# %%
sns.countplot(y=df["2 How old are you? "])
print(df["2 How old are you? "].value_counts())
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# Age of the respondent
# - Majority of the respondent were categorized Between 31-40 years of age.
# - 51 years and above age category has least (19) number of respondents

# %%
sns.countplot(y=df["3 Which city do you shop online from?"])
print(df["3 Which city do you shop online from?"].value_counts())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# - Bangalore city has highest number (58) of online shopper
# - Bulandshahr city has lowest number (2) of online shopper

# %%
plt.figure(figsize=(22,12))
sns.countplot(y=df["4 What is the Pin Code of where you shop online from?"])
print(df["4 What is the Pin Code of where you shop online from?"].value_counts())
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 250001     9
# 173229     9
# 173212     9
# 560010     8
# 132036     8
# 122018     8
# 560037     8
# 110008     7
# 110011     7
# 201306     7
# 110014     6
# 110018     6
# 201305     5
# 201008     5
# 201009     5
# 201312     5
# 244001     5
# 530068     5
# 122009     4
# 201001     4
# 560003     4
# 201304     4
# 110009     4
# 201303     4
# 560002     4
# 560018     4
# 110042     4
# 110030     4
# 201005     4
# 110039     4
# 560013     3
# 203001     2
# 203202     1
# 560001     1
# 203207     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %% [markdown]
# - Pincode 201308 has highest number (38) of online shopper
# - Pincode 203202, 560001, 203207 has lowest number (1) of online shopper

# %%
sns.countplot(y=df["5 Since How Long You are Shopping Online ?"])
print(df["5 Since How Long You are Shopping Online ?"].value_counts())
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# - Respondent categorized in Above 4 years of online shopping experience has highest count (98).
# - Whereas category with 1-2 years of online shopping experience has lowest number of respondents (16)

# %%
sns.countplot(y=df["6 How many times you have made an online purchase in the past 1 year?"])
print(df["6 How many times you have made an online purchase in the past 1 year?"].value_counts())
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# - Majority of respondents (114) shopped between 31-40 times in a year.
# - Minority of respondents (6) shopped more than 42 times in a year.

# %%
sns.countplot(df["7 How do you access the internet while shopping on-line?"])
print(df["7 How do you access the internet while shopping on-line?"].value_counts())
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# - Majority (142) of the respondent accessed internet through mobile internet whereas
# - Minority (4) of the respondent accessed internet through Dial-up

# %%
sns.countplot(y=df["8 Which device do you use to access the online shopping?"])
print(df["8 Which device do you use to access the online shopping?"].value_counts())
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# - (141) Highest number of people used Laptop device to access online shopping
# - Least (12) number of perople used Tablet device.

# %%
sns.countplot(df["9 What is the screen size of your mobile device?						                                        "])
print(df["9 What is the screen size of your mobile device?						                                        "].value_counts())
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %% [markdown]
# - Maximum (134) respondent has screen size of more than 5.5 inches i.e Others Category
# - Respondent with screen size of 5 inches were the least.

# %%
sns.countplot(df["10 What is the operating system (OS) of your device?				                                          "])
print(df["10 What is the operating system (OS) of your device?				                                          "].value_counts())
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %% [markdown]
# - 122 respondents has OS Window/windows Mobile
# - 85 respondents has OS Android
# - 62 respondents has OS IOS/Mac

# %%
sns.countplot(df["11 What browser do you run on your device to access the website?			                                                          "])
print(df["11 What browser do you run on your device to access the website?			                                                          "].value_counts())
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %% [markdown]
# - Most of the respondent (216) used google chrome while handful used (5) Mozilla Firefox, which was least among all the respondents.

# %%
sns.countplot(df["12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   "])
print(df["12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   "].value_counts())
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %% [markdown]
# - Search Engine was used as a channel by majority (230) of respondents
# - Content Marketing was used as channel by 20 respondents
# - Display Adverts was used as a channel by least number (19) of respondents

# %%
plt.figure(figsize=(10,7))
sns.countplot(df["13 After first visit, how do you reach the online retail store?				                                                   "])
print(df["13 After first visit, how do you reach the online retail store?				                                                   "].value_counts())
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %% [markdown]
# - Majority (87) of the respondents reached online reatil store 2nd time through search engine
# - Minority (8) accessed online reatil store through social media

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["14 How much time do you explore the e- retail store before making a purchase decision?                                                                   "])
print(df["14 How much time do you explore the e- retail store before making a purchase decision?                                                                   "].value_counts())
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %% [markdown]
# - Majority (123) of the respondents spend more than 15 min exploring e-retail store before purchasing while
# - Minority (14) spend between 1-5 min exploring e-retail store before purchasing

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["15 What is your preferred payment Option?					                                                                                                                               "])
print(df["15 What is your preferred payment Option?					                                                                                                                               "].value_counts())
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %% [markdown]
# - Credit/Debit cards was used by 148 people
# - Cash on delivery (CoD) was used by 76 people
# - E-wallets (Paytm, Freecharge etc.) was used by 45 people

# %%
sns.countplot(df["16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?							                                                   "])
print(df["16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?							                                                   "].value_counts())
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %% [markdown]
# - Majority (171) respondent sometimes abandoned their shopping cart while minority of respondent (15) abandoned frequently

# %%
plt.figure(figsize=(12,5))
sns.countplot(df["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       "])
print(df["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       "].value_counts())
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %% [markdown]
# - Majority respondent said that they abandoned shooping cart because they got better alternative offer
# - Least group of respondent said no preferred mode of payment was the cause for abandoning the cart.

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["18 The content on the website must be easy to read and understand"])
print(df["18 The content on the website must be easy to read and understand"].value_counts())
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# - Majority (164) of the online shopper strongly agree that content of website should be easy to read
# - Minority (7) of the online shopper has indfifferent opinion than one that are suggested

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["19 Information on similar product to the one highlighted  is important for product comparison"])
print(df["19 Information on similar product to the one highlighted  is important for product comparison"].value_counts())
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %% [markdown]
# - 116 respondents strongly agree that information on similar product to the one highlighted  is important for product comparison
# - very small group of 18 respondents disagree that information on similar product to the one highlighted  is important for product comparison

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["20 Complete information on listed seller and product being offered is important for purchase decision."])
print(df["20 Complete information on listed seller and product being offered is important for purchase decision."].value_counts())
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [markdown]
# - Majority of 101 respondents agree that complete information on listed seller and product being offered is important for purchase decision
# - While minority of 11 respondents disagreed

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["21 All relevant information on listed products must be stated clearly"])
print(df["21 All relevant information on listed products must be stated clearly"].value_counts())
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# - Majority of 132 respondents agree that all relevant information on listed products must be stated clearly
# - While minority of 12 respondents disagreed

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["22 Ease of navigation in website"])
print(df["22 Ease of navigation in website"].value_counts())
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %% [markdown]
# - Majority of 141 respondents strongly agree that there should be ease in navigation of website
# - While minority of 5 respondents disagreed

# %%
plt.figure(figsize=(9,5))
sns.countplot(df["23 Loading and processing speed"])
print(df["23 Loading and processing speed"].value_counts())
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %% [markdown]
# - Majority of 115 respondents strongly agree that loading and processing speed of online shopping website matters
# - While minority of 12 respondents belonged to either strongly disagreeing group or group that had indifferent opninion

# %%
plt.figure(figsize=(9,5))
sns.countplot(df["24 User friendly Interface of the website"])
print(df["24 User friendly Interface of the website"].value_counts())
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %% [markdown]
# - Majority of 189 respondents strongly agree that user friendly interface of online shopping website matters
# - While minority of 5 respondents belonged to group that had indifferent opninion

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["25 Convenient Payment methods"])
print(df["25 Convenient Payment methods"].value_counts())
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %% [markdown]
# - Majority of 159 respondents strongly agree that convenient payment methods is important
# - While minority of 30 respondents disagreed

# %%
plt.figure(figsize=(6,5))
sns.countplot(df["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"])
print(df["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"].value_counts())
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %% [markdown]
# - Majority of 141 respondents strongly agree that trust of online retail store regarding fulfilling its part of the transaction at the stipulated time is important.
# - While minority of 12 respondents had indifferent opinion

# %%
plt.figure(figsize=(6,5))
sns.countplot(df["27 Empathy (readiness to assist with queries) towards the customers"])
print(df["27 Empathy (readiness to assist with queries) towards the customers"].value_counts())
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %% [markdown]
# - Majority of 194 respondents strongly agree that Empathy (readiness to assist with queries) towards the customers is important.
# - While minority of 15 respondents had indifferent opinion

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["28 Being able to guarantee the privacy of the customer"])
print(df["28 Being able to guarantee the privacy of the customer"].value_counts())
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# - Majority of 185 respondents strongly agree that being able to guarantee the privacy of the customer is important.
# - While minority of 26 respondents had indifferent opinion

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"])
print(df["29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"].value_counts())
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %% [markdown]
# - Majority of 149 respondents strongly agree that responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.) is important.
# - While minority of 11 respondents strongly disagreed.

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["30 Online shopping gives monetary benefit and discounts"])
print(df["30 Online shopping gives monetary benefit and discounts"].value_counts())
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %% [markdown]
# - Majority of 105 respondents strongly agree that online shopping gives monetary benefit and discounts.
# - While minority of 11 respondents disagreed.

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["31 Enjoyment is derived from shopping online"])
print(df["31 Enjoyment is derived from shopping online"].value_counts())
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %% [markdown]
# - Majority of 86 respondents strongly agree that enjoyment is derived from shopping online
# - While minority of 19 respondents disagreed.

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["32 Shopping online is convenient and flexible"])
print(df["32 Shopping online is convenient and flexible"].value_counts())
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %% [markdown]
# - Majority of 146 respondents strongly agree that shopping online is convenient and flexible
# - While minority of 12 respondents disagreed.

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["33 Return and replacement policy of the e-tailer is important for purchase decision"])
print(df["33 Return and replacement policy of the e-tailer is important for purchase decision"].value_counts())
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# - Majority of 198 respondents strongly agree that return and replacement policy of the e-tailer is important for purchase decision
# - While minority of 20 respondents disagreed.

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["34 Gaining access to loyalty programs is a benefit of shopping online"])
print(df["34 Gaining access to loyalty programs is a benefit of shopping online"].value_counts())
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %% [markdown]
# - Majority of 115 respondents strongly agree that gaining access to loyalty programs is a benefit of shopping online
# - While minority of 11 respondents strongly disagreed.

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["35 Displaying quality Information on the website improves satisfaction of customers"])
print(df["35 Displaying quality Information on the website improves satisfaction of customers"].value_counts())
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# - Majority of 133 respondents strongly agree that displaying quality Information on the website improves satisfaction of customers
# - While minority of 86 respondents belonged to group with indifferent opinion.

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["36 User derive satisfaction while shopping on a good quality website or application"])
print(df["36 User derive satisfaction while shopping on a good quality website or application"].value_counts())
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %% [markdown]
# - Majority of 175 respondents strongly agree that user derive satisfaction while shopping on a good quality website or application
# - While minority of 8 respondents disagreed.

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["37 Net Benefit derived from shopping online can lead to users satisfaction"])
print(df["37 Net Benefit derived from shopping online can lead to users satisfaction"].value_counts())
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %% [markdown]
# - Majority of 164 respondents strongly agree that Net Benefit derived from shopping online can lead to users satisfaction
# - While minority of 11 respondents disagreed.

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["38 User satisfaction cannot exist without trust"])
print(df["38 User satisfaction cannot exist without trust"].value_counts())
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %% [markdown]
# - Majority of 122 respondents strongly agree that user satisfaction cannot exist without trust
# - While minority of 5 respondents belonged to category with indiffrent opnion .

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["39 Offering a wide variety of listed product in several category"])
print(df["39 Offering a wide variety of listed product in several category"].value_counts())
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %% [markdown]
# - Majority of 111 respondents strongly agree that Offering a wide variety of listed product in several category is important
# - While minority of 7 respondents disagreed .

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["40 Provision of complete and relevant product information"])
print(df["40 Provision of complete and relevant product information"].value_counts())
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %% [markdown]
# - Majority of 135 respondents strongly agree that provision of complete and relevant product information is important
# - While minority of 5 respondents disagreed .

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["41 Monetary savings"])
print(df["41 Monetary savings"].value_counts())
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# - Majority of 148 respondents strongly agree with monetary saving
# - While minority of 15 respondents belonged to category with indifferent opinion .

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["42 The Convenience of patronizing the online retailer"])
print(df["42 The Convenience of patronizing the online retailer"].value_counts())
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %% [markdown]
# - Majority of 138 respondents agree with the Convenience of patronizing the online retailer
# - While minority of 54 respondents belonged to category that strongly agreed .

# %%
plt.figure(figsize=(7,5))
sns.countplot(df["43 Shopping on the website gives you the sense of adventure"])
print(df["43 Shopping on the website gives you the sense of adventure"].value_counts())
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %% [markdown]
# - Majority of 101 respondents agree that Shopping on the website gives you the sense of adventure
# - While minority of 5 respondents strongly disagreed .

# %%
plt.figure(figsize=(9,5))
sns.countplot(df["44 Shopping on your preferred e-tailer enhances your social status"])
print(df["44 Shopping on your preferred e-tailer enhances your social status"].value_counts())
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %% [markdown]
# - Majority of 100 respondents had indifferent opinion about statement that Shopping on your preferred e-tailer enhances your social status
# - While minority of 29 respondents disagreed

# %%
plt.figure(figsize=(9,5))
sns.countplot(df["45 You feel gratification shopping on your favorite e-tailer"])
print(df["45 You feel gratification shopping on your favorite e-tailer"].value_counts())
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [markdown]
# - Majority of 101 respondents strongly agree that You feel gratification shopping on your favorite e-tailer
# - While minority of 18 respondents strongly disagreed

# %%
plt.figure(figsize=(9,5))
sns.countplot(df["46 Shopping on the website helps you fulfill certain roles"])
print(df["46 Shopping on the website helps you fulfill certain roles"].value_counts())
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %% [markdown]
# - Majority of 88 respondentsagree that Shopping on the website helps you fulfill certain roles
# - While minority of 22 respondents disagreed

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["47 Getting value for money spent"])
print(df["47 Getting value for money spent"].value_counts())
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# - Majority of 149 respondents agree with Getting value for money spent
# - While minority of 38 respondents belonged to category with indifferent opinion .

# %% [markdown]
# # Analysis of website features

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '])
print(df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 82 have shopped from all five (i.e. Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com) online shopping website mentioned in the options
# - While minority of 7 respondents shopped only on Amazon.in, Flipkart.com, Paytm.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Easy to use website or application'])
print(df['Easy to use website or application'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 64 have mentioned all five (i.e. Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com) online shopping website as easy to use website or application
# - While minority of 7 respondents have mentioned Amazon.in, Paytm.com

# %%
plt.figure(figsize=(12,6))
sns.countplot(y=df['Visual appealing web-page layout'])
print(df['Visual appealing web-page layout'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 87 have mentioned Amazon.in, Flipkart.com as the only 2 website with Visual appealing web-page layout
# - While minority of 11 respondents have mentioned Amazon.in,Flipkart.com, Paytm.com, Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Wild variety of product on offer'])
print(df['Wild variety of product on offer'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 130 have mentioned Amazon.in, Flipkart.com online shopping website as having Wild variety of product on offer
# - While minority of 7 respondents have mentioned only Paytm.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Complete, relevant description information of products'])
print(df['Complete, relevant description information of products'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 100 have mentioned Amazon.in, Flipkart.com shopping website as having Complete, relevant description information of products
# - While minority of 7 respondents have mentioned Amazon.in,Flipkart.com, Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Fast loading website speed of website and application'])
print(df['Fast loading website speed of website and application'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 51 have mentioned Amazon.in as the only website having fast loading speed
# - While minority of 8 respondents have mentioned only Flipkart.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Reliability of the website or application'])
print(df['Reliability of the website or application'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 61 have mentioned Amazon.in as the only website having website Reliability
# - While minority of 12 respondents have mentioned only Paytm.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Quickness to complete purchase'])
print(df['Quickness to complete purchase'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 66 have mentioned Amazon.com website as the quickest of all the website to complete the purchase
# - While minority of 14 respondents have mentioned Myntra.com,Flipkart.com,Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Availability of several payment options'])
print(df['Availability of several payment options'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 65 have mentioned Amazon.in, Flipkart.com as the only 2 websites with several payment options
# - While minority of 8 respondents have mentioned only Flipkart.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Speedy order delivery '])
print(df['Speedy order delivery '].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 107 have mentioned Amazon.in as only website having Speedy order delivery
# - While minority of 14 respondents mentioned Myntra.com,Flipkart.com, Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Privacy of customers’ information'])
print(df['Privacy of customers’ information'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 71 have mentioned Amazon.in as only website having Privacy of customers’ information
# - While minority of 7 respondents mentioned Amazon.in,Flipkart.com, Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Security of customer financial information'])
print(df['Security of customer financial information'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 51 have mentioned Amazon.in as only website having Security of customer financial information
# - While minority of 11 respondents mentioned Amazon.in,Flipkart.com, Paytm.com,

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Perceived Trustworthiness'])
print(df['Perceived Trustworthiness'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 76 have mentioned Amazon.in as only website having Perceived Trustworthiness
# - While minority of 11 respondents mentioned Amazon.in,Flipkart.com, Paytm.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Presence of online assistance through multi-channel'])
print(df['Presence of online assistance through multi-channel'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 61 have mentioned Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com as the only website with online assistance through multi-channel
# - While minority of 11 respondents mentioned only Flipkart.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Longer time to get logged in (promotion, sales period)'])
print(df['Longer time to get logged in (promotion, sales period)'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 57 have mentioned Amazon.in as the only website having Longer log in time during (promotion, sales period)
# - While minority of 8 respondents mentioned only Flipkart.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Longer time in displaying graphics and photos (promotion, sales period)'])
print(df['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 69 have mentioned Amazon.in, Flipkart.com as only 2 websites having longer displaying time during (promotion, sales period)
# - While minority of 13 respondents mentioned Amazon.in, Paytm.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Late declaration of price (promotion, sales period)'])
print(df['Late declaration of price (promotion, sales period)'].value_counts())    
plt.ylabel("")
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 75 have mentioned Myntra.com as the only website having Late declaration of price (promotion, sales period)
# - While minority of 5 respondents mentioned Amazon.in,Flipkart.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Longer page loading time (promotion, sales period)'])
print(df['Longer page loading time (promotion, sales period)'].value_counts())    
plt.ylabel("")
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 61 have mentioned Myntra.com as the only website having Longer page loading time (promotion, sales period)
# - While minority of 7 respondents mentioned Amazon.in,Paytm.com, Myntra.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Limited mode of payment on most products (promotion, sales period)'])
print(df['Limited mode of payment on most products (promotion, sales period)'].value_counts())    
plt.ylabel("")
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 87 have mentioned Snapdeal.com as the only website having Limited mode of payment on most products (promotion, sales period)
# - While minority of 7 respondents mentioned Myntra.com, Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Longer delivery period'])
print(df['Longer delivery period'].value_counts())    
plt.ylabel("")
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 72 have mentioned Paytm.com as the only website having longer delivery period
# - While minority of 26 respondents mentioned Myntra.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Change in website/Application design'])
print(df['Change in website/Application design'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 96 have mentioned Amazon.in as the only website having change in website/Application design
# - While minority of 7 respondents mentioned Flipkart.com, Myntra.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Frequent disruption when moving from one page to another'])
print(df['Frequent disruption when moving from one page to another'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 53 have mentioned Amazon.in as the only website having Frequent disruption when moving from one page to another
# - While minority of 11 respondents mentioned Flipkart.com, Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Website is as efficient as before'])
print(df['Website is as efficient as before'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 87 have mentioned Amazon.in as the only website having efficiency as before
# - While minority of 11 respondents mentioned Snapdeal.com

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['Which of the Indian online retailer would you recommend to a friend?'])
print(df['Which of the Indian online retailer would you recommend to a friend?'].value_counts())    
plt.ylabel("")
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64
# Text(0, 0.5, '')

# %% [markdown]
# - Majority respondents of 79 have mentioned Amazon.in as only website recommendation to a friend
# - While minority of 11 respondents mentioned Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['3 Which city do you shop online from?'],hue=df['2 How old are you? '])

# %% [markdown]
# Delhi
# - Majority of online shopper belong to 41-50 years age group
# - Minority belong to 51 and above years age agroup
#
# Greater Noida
# - Majority of online shopper belong to 31-40 years age group
# - Minority belong to both less than 20 years and 51 and above years age group
#
# Karnal
# - Majority of online shopper belong to 21-30 years age group
# - Minority belong to less than 20 years age group
#
# Bangalore
# - Majority of online shopper belong to 21-30 years age group
# - Minority belong to less than 31-40 age group
#
# Noida
# - Majority of online shopper belong to 31-40 age group
# - Minority belong to less than 20 years age group
#
# Solan
# - Majority of online shopper belong to less than 20 years age group
# - Minority belong to 31-40 and 41-50 years age group
#
# Moradabad
# - Majority of online shopper belong to 31-40 years age group
# - Minority belong to rest of all the age group
#
# Gurgaon
# - Majority of online shopper belong to 51 and above years age group
# - Minority belong to less than 20 years,21-30 years and 41-50 years age group
#
# Merrut
# - Majority of online shopper belong to 21-30 age group
# - Minority belong to less than 20 years and 51 and above years age group
#
# Ghaziabad
# - Majority of online shopper belong to 31-40 years age group
# - Minority belong to 51 and above years age group
#
# Bulandshahr
# - Majority of online shopper belong to 31-40 years age group
# - Minority belong to rest all the age group

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['3 Which city do you shop online from?'],hue=df['1Gender of respondent'])

# %% [markdown]
# - Majority of female respondents shopped from Noida while minority of them shopped from Merrut
# - Majority of male respondents shopped from Delhi while minority of them shopped from Greater Noida, Gurgaon and Ghaziabad

# %% [markdown]
# # Encoding Categorical Features

# %%
df.iloc[:,3]
# Out:
# 0      110009
# 1      110030
# 2      201308
# 3      132001
# 4      530068
#         ...
# 264    173212
# 265    201008
# 266    560010
# 267    173229
# 268    201009
# Name: 4 What is the Pin Code of where you shop online from?, Length: 269, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder
enc1=LabelEncoder()
enc2=OrdinalEncoder()

n=[1,4,5,13,15]
for i in range(17):
  if i in n:
    if df.iloc[:,i].dtypes!='int64':
      df.iloc[:,i]=enc2.fit_transform(df.iloc[:,i].values.reshape(-1,1))
  else:
    if df.iloc[:,i].dtypes!='int64':
      df.iloc[:,i]=enc1.fit_transform(df.iloc[:,i].values.reshape(-1,1))
    

for i in range(17,47):
  df.iloc[:,i]=enc2.fit_transform(df.iloc[:,i].values.reshape(-1,1))


for i in range(47,df.shape[1]):
  df.iloc[:,i]=enc1.fit_transform(df.iloc[:,i].values.reshape(-1,1))

# %% [markdown]
# - Column 0-16 (Column 1,4,5,13,15 are ordinal) contain nominal value such as gender, location etc
#
# - Column 3 is numeric
#
# - Column 17-46 contain ordinal value such as Strongly agree, agree, disagree etc
#
# - Column 47-71 contain nominal value such as amazon.in, flipkart.com etc

# %%
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      1                  1.0
# 1                      0                  0.0
# 2                      0                  0.0
# 3                      1                  0.0
# 4                      0                  0.0
#
#    3 Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                         3.0
# ...

# %% [markdown]
# # Separating input features and target column

# %%
x=df.drop(["Which of the Indian online retailer would you recommend to a friend?"], axis=1)
x.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      1                  1.0
# 1                      0                  0.0
# 2                      0                  0.0
# 3                      1                  0.0
# 4                      0                  0.0
#
#    3 Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                         3.0
# ...

# %%
y=df["Which of the Indian online retailer would you recommend to a friend?"]
y.head()
# Out:
# 0    6
# 1    3
# 2    5
# 3    1
# 4    3
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# - The 71st column named 'Which of the Indian online retailer would you recommend to a friend?' is selected as the target column, assuming that person will recommend only those online shopping website, which he/she has frequently used, thus indicating customer retention by that website.
#
# - And hence it can be used to determine factors that are responsible for customer retention.

# %% [markdown]
# # Oversampling

# %%
y.value_counts()
# Out:
# 0    79
# 1    62
# 6    39
# 3    30
# 5    20
# 2    15
# 4    13
# 7    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# - The class distribution is imbalanced.

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()
x_new,y_new=smt.fit_resample(x,y)
y=y_new
y.value_counts()
# Out:
# 6    79
# 3    79
# 5    79
# 1    79
# 4    79
# 7    79
# 0    79
# 2    79
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# # Scaling input features

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score,accuracy_score
from sklearn.model_selection import train_test_split,cross_val_score

mns=MinMaxScaler()
s=mns.fit_transform(x_new)
x=pd.DataFrame(s,columns=x_new.columns)

# %% [markdown]
# - MinMax Scaler scales the data to a fixed range between 0 and 1 which makes it easier for model to learn and understand.

# %% [markdown]
# # Detecting Top Features

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2


select_features = SelectKBest(score_func=chi2)
fit_features = select_features.fit(X_train,y_train)

xscores = pd.DataFrame(fit_features.scores_)
xcolumns = pd.DataFrame(x.columns)

feature_score = pd.concat([xcolumns,xscores],axis=1)
feature_score.columns = ['Column Name','Score'] 
dff=pd.DataFrame(feature_score.nlargest(20,'Score'))
display(dff)
# Out:
#                                           Column Name       Score
# 16  17 Why did you abandon the “Bag”, “Shopping Ca...  193.183286
# 12  13 After first visit, how do you reach the onl...  151.672015
# 9   10 What is the operating system (OS) of your d...  146.557365
# 42  43 Shopping on the website gives you the sense...  142.866275
# 10  11 What browser do you run on your device to a...  140.658218
# 22                    23 Loading and processing speed  139.509495
# 69                  Website is as efficient as before  137.872816
# 18  19 Information on similar product to the one h...  137.358052
# 45  46 Shopping on the website helps you fulfill c...  131.518074
# 28  29 Responsiveness, availability of several com...  120.373738
# 46                   47 Getting value for money spent  111.523997
# 62  Longer time in displaying graphics and photos ...  110.603018
# 57                  Privacy of customers’ information  107.199783
# ...

# %%
plt.figure(figsize=(22,7))
plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
plt.xlabel("Features",fontsize=15)
plt.ylabel("Score",fontsize=15)
plt.show()

# %% [markdown]
# #Conclusion
#
# Features obtained using selectkbest method play crucial role in online shopping website recommendation (assuming that person recommends website which they frequently operate on and thus indicating customer retention by that website)

# %% [markdown]
# ___________________________________________________________________________________________________
